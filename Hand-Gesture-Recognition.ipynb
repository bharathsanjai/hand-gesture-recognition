# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathsanjai/hand-gesture-recognition/blob/main/Neural_Nets_Project_Starter_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
# Running on GPU

import platform
import tensorflow as tf

print("Python version: ", platform.python_version())
print("TensorFlow version: ", tf.__version__)

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    print('GPU not found. Running on CPU.')
else:
    print('GPU found. Running on GPU.')
# Out:
# Python version:  3.10.12
# TensorFlow version:  2.12.0
# GPU found. Running on GPU.

# %%
# !pip install imageio
# Out:
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
# from scipy.misc import imread, imresize
from skimage.transform import resize
from imageio import imread
import imageio
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
# tf.set_random_seed(30)
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('/content/drive/My Drive/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/content/drive/My Drive/Project_data/val.csv').readlines())
batch_size = 10 # experiment with the batch size

# %%
# np.random.seed(5)
# random_numbers = np.random.randint(0, 30, size=18)
# random_numbers
# Out:
# array([ 3, 14, 15, 29,  6, 22, 16,  9,  8,  4,  7, 27, 16, 16,  7, 12, 15,
#        17])

# %%
# samples_per_folder = 18

# def batchsize(folder_list):
#   result = math.ceil(folder_list.length *  samples_per_folder / batch_size)
#   print('result is =', result)

# %%
# batch_size = 10 # experiment with the batch size
# selecting alternate frames
# seq_idx =  np.round(np.linspace(0, 29, 20)).astype(int)
# image dimensions
# dim_x, dim_y = 120, 120

# %%
def cropResize(image, y, z):
    h, w = image.shape

    # if smaller image crop at center for 120x120
    if w == 160:
        image = image[:120, 20:140]

    # resize every image
    return resize(image, (y,z))

# %%
def getImgTensor(n_frames):
    img_idx = np.round(np.linspace(0, 29, n_frames)).astype(int)
    return [img_idx, 120, 120, 3]

# define image tensor size
img_tensor = getImgTensor(20)
print ('# img_tensor =', img_tensor)
# Out:
# # img_tensor = [array([ 0,  2,  3,  5,  6,  8,  9, 11, 12, 14, 15, 17, 18, 20, 21, 23, 24,
#        26, 27, 29]), 120, 120, 3]

# %%
def normalizeImage(image):
    # applying normalization
    return image/255.0

# %%
def preprocessImage(image, y, z):
    return normalizeImage(cropResize(image, y, z))

# %%
def genhelper(source_path, folder_list, batch_size, img_tensor, t, batch):
  [x,y,z] = [len(img_tensor[0]),img_tensor[1], img_tensor[2]]
  # img_idx = [1,4,5,6,7,9,21]
  # print('IMG tensor ...', img_tensor[0])
  img_idx = img_tensor[0]
  # print('IMG DX list', img_idx)
  batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
  batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
  for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                # print(' Foder currently reading : ='+ source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0])
                # print('IMGS...', imgs)

                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    # print('image index count : = ', idx , ' ; item =', item)
                    # print('Batch: = ', batch , ' ; Batch size: =', batch_size , ' ; index =' , batch*batch_size)
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes

                    batch_data[folder,idx,:,:,0] = preprocessImage(image[:, :, 0], y, z) #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = preprocessImage(image[:, :, 1], y, z) #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = preprocessImage(image[:, :, 2], y, z) #normalise and feed in the image

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
  return batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size, img_tensor):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    # print('folder list length = ', folder_list)
    # [x,y,z] = [len(img_tensor[0]),img_tensor[1], img_tensor[2]]
    # img_idx = img_tensor[0]

    while True:
        t = np.random.permutation(folder_list)
        num_batches = int(len(folder_list)/batch_size) # calculate the number of batches
        print('; Num of batches =', num_batches)
        for batch in range(num_batches): # we iterate over the number of batches
            # print('; Current Batch =', batch)
            yield genhelper(source_path, folder_list, batch_size, img_tensor, t, batch)#you yield the batch_data and the batch_labels, remember what does yield do


        # write the code for the remaining data points which are left after full batches
        if len(folder_list)%batch_size != 0:
          batch_size = len(folder_list)%batch_size
          yield genhelper(source_path, folder_list, batch_size, img_tensor, t, batch)#you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/content/drive/My Drive/Project_data/train'
val_path = '/content/drive/My Drive/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %%
# check complete batch shape
sample_generator = generator(train_path, train_doc, 32, img_tensor)
sample_batch_data, sample_batch_labels = next(sample_generator)
print(sample_batch_data.shape)

# %%
# validation batch sample
sample_val_generator = generator(val_path, val_doc, batch_size, img_tensor)
sample_val_batch_data, sample_val_batch_labels = next(sample_val_generator)
print(sample_val_batch_data.shape)

# %%
def make3dFilter(x):
    return tuple([x]*3)

def make2dFilter(x):
    return tuple([x]*2)

print(make2dFilter(5))
# Out:
# (5, 5)

# %%
 inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])
 print(inputShape)
# Out:
# (20, 120, 120, 3)

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# #write your model here

# # Create a Sequential model
# model = Sequential()

# # Add Conv3D layer
# model.add(Conv3D(filters=16, kernel_size=(5, 5, 5), activation='relu', input_shape=(inputShape)))

# # Add Conv3D layer
# model.add(Conv3D(filters=32, kernel_size=(3, 3, 3), activation='relu'))

# # Add Conv3D layer
# model.add(Conv3D(filters=64, kernel_size=(3, 3, 3), activation='relu'))

# # Add MaxPooling3D layer
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# # Add Flatten layer
# model.add(Flatten())

# # Add Dense layers
# model.add(Dense(128, activation='relu'))
# model.add(Dense(64, activation='softmax'))  # num_classes is the number of classes in your problem

# Compile the model
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
# optimiser = 'adam'
# model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# print (model.summary())

# %%
def defineModel(img_tensor):
    inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

    model = Sequential([
        Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
        MaxPooling3D(make3dFilter(2), padding='same'),
        BatchNormalization(),

        Conv3D(32, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Conv3D(64, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Flatten(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(5, activation='softmax')
    ])
    model.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    return model

model = defineModel(img_tensor)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 16, 116, 116, 16)  6016
#
#  max_pooling3d (MaxPooling3D  (None, 8, 58, 58, 16)    0
#  )
#
#  batch_normalization (BatchN  (None, 8, 58, 58, 16)    64
#  ormalization)
#
#  conv3d_1 (Conv3D)           (None, 6, 56, 56, 32)     13856
#
#  max_pooling3d_1 (MaxPooling  (None, 6, 28, 28, 32)    0
#  3D)
#
#  batch_normalization_1 (Batc  (None, 6, 28, 28, 32)    128
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 4, 26, 26, 64)     55360
#
#  max_pooling3d_2 (MaxPooling  (None, 4, 13, 13, 64)    0
#  3D)
#
#  batch_normalization_2 (Batc  (None, 4, 13, 13, 64)    256
#  hNormalization)
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dense (Dense)               (None, 128)               5537920
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 5,622,949
# Trainable params: 5,622,341
# Non-trainable params: 608
# _________________________________________________________________

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)# write the REducelronplateau code here
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
num_epochs = 10

# %%
import matplotlib.pyplot as plt

# %%
def plotModelHistory(h):
    fig, ax = plt.subplots(1, 2, figsize=(15,4))
    ax[0].plot(h.history['loss'])
    ax[0].plot(h.history['val_loss'])
    ax[0].legend(['loss','val_loss'])
    ax[0].title.set_text("Train loss vs Validation loss")

    ax[1].plot(h.history['categorical_accuracy'])
    ax[1].plot(h.history['val_categorical_accuracy'])
    ax[1].legend(['categorical_accuracy','val_categorical_accuracy'])
    ax[1].title.set_text("Train accuracy vs Validation accuracy")
    plt.show()

    print("Max. Training Accuracy", max(h.history['categorical_accuracy']))
    print("Max. Validaiton Accuracy", max(h.history['val_categorical_accuracy']))

# %% [markdown]
# ### Experiment 1 - Base Model

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
# @title Base model
base_model_history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %%
plotModelHistory(base_model_history)
# Out:
# Max. Training Accuracy 0.42786070704460144
# Max. Validaiton Accuracy 0.4300000071525574

# %% [markdown]
# #### Max train and val accuracy is not performing good hence will conduct more experiments

# %% [markdown]
# ### Experiment 2 - Testing Batch size and frames

# %%
def batchsizetester(n_frames, batch_size):
  # n_frames = 16
  num_epochs = 3
  # batch_size = 64

  img_tensor = getImgTensor(n_frames)
  print("Using frames as", img_tensor[0])
  train_generator = generator(train_path, train_doc, batch_size, img_tensor)
  val_generator = generator(val_path, val_doc, batch_size, img_tensor)

  if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
  else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

  if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
  else:
    validation_steps = (num_val_sequences//batch_size) + 1

  model = defineModel(img_tensor)

  model_history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

  plotModelHistory(model_history)

# %%
batchsizetester(22, 64)

# %%
batchsizetester(15, 32)

# %% [markdown]
# ### Batch size is not helping much and cleared output to reduce page size. hence we will try out other options

# %% [markdown]
# ### Experiment 3
# #### Frames-16, Epoc-25

# %% [markdown]
# Model 1 - Frames-16, Epoc-25

# %%
n_frames = 16
num_epochs = 15
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

# %%
model1 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.50),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.50),

    Dense(5, activation='softmax')
], name="conv_3d1")

# %%
model1.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model1.summary())
# Out:
# Model: "conv_3d1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_3 (Conv3D)           (None, 12, 116, 116, 16)  6016
#
#  max_pooling3d_3 (MaxPooling  (None, 6, 58, 58, 16)    0
#  3D)
#
#  batch_normalization_5 (Batc  (None, 6, 58, 58, 16)    64
#  hNormalization)
#
#  conv3d_4 (Conv3D)           (None, 4, 56, 56, 32)     13856
#
#  max_pooling3d_4 (MaxPooling  (None, 4, 28, 28, 32)    0
#  3D)
#
#  batch_normalization_6 (Batc  (None, 4, 28, 28, 32)    128
#  hNormalization)
#
#  conv3d_5 (Conv3D)           (None, 2, 26, 26, 64)     55360
#
#  max_pooling3d_5 (MaxPooling  (None, 2, 13, 13, 64)    0
#  3D)
#
#  batch_normalization_7 (Batc  (None, 2, 13, 13, 64)    256
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 21632)             0
#
#  dense_3 (Dense)             (None, 128)               2769024
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 2,854,053
# Trainable params: 2,853,445
# Non-trainable params: 608
# _________________________________________________________________
# None

# %%
model1_history = model1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
            callbacks=callbacks_list, validation_data=val_generator,
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# <ipython-input-27-8cfbb15ae49d>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model1_history = model1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# Source path =  /content/drive/My Drive/Project_data/train ; batch size = 64
# ; Num of batches = 10
# <ipython-input-10-4d0922c185e1>:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/15
# 10/11 [==========================>...] - ETA: 3:52 - loss: 1.8487 - categorical_accuracy: 0.3438; Num of batches = 28
# 11/11 [==============================] - ETA: 0s - loss: 1.8307 - categorical_accuracy: 0.3484  Source path =  /content/drive/My Drive/Project_data/val ; batch size = 64
# ; Num of batches = 1
# ; Num of batches = 2
#
# Epoch 1: saving model to model_init_2023-09-0204_16_33.795128/model-00001-1.83072-0.34842-7.42654-0.20000.h5
# 11/11 [==============================] - 2420s 240s/step - loss: 1.8307 - categorical_accuracy: 0.3484 - val_loss: 7.4265 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/15
# 11/11 [==============================] - ETA: 0s - loss: 1.4241 - categorical_accuracy: 0.4980; Num of batches = 3
#
# Epoch 2: saving model to model_init_2023-09-0204_16_33.795128/model-00002-1.42407-0.49802-3.72692-0.28125.h5
# 11/11 [==============================] - 113s 11s/step - loss: 1.4241 - categorical_accuracy: 0.4980 - val_loss: 3.7269 - val_categorical_accuracy: 0.2812 - lr: 0.0010
# Epoch 3/15
# 11/11 [==============================] - ETA: 0s - loss: 1.4214 - categorical_accuracy: 0.4941
# Epoch 3: saving model to model_init_2023-09-0204_16_33.795128/model-00003-1.42136-0.49407-7.63977-0.25000.h5
# 11/11 [==============================] - 107s 11s/step - loss: 1.4214 - categorical_accuracy: 0.4941 - val_loss: 7.6398 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch
- val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 13/15
# 11/11 [==============================] - ETA: 0s - loss: 0.9428 - categorical_accuracy: 0.6631
# Epoch 13: saving model to model_init_2023-09-0204_16_33.795128/model-00013-0.94280-0.66310-2.88198-0.37500.h5
# 11/11 [==============================] - 23s 2s/step - loss: 0.9428 - categorical_accuracy: 0.6631 - val_loss: 2.8820 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 14/15
#  9/11 [=======================>......] - ETA: 3s - loss: 1.1248 - categorical_accuracy: 0.5294; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 1.0982 - categorical_accuracy: 0.5348; Num of batches = 25
#
# Epoch 14: saving model to model_init_2023-09-0204_16_33.795128/model-00014-1.09823-0.53476-2.34761-0.37500.h5
# 11/11 [==============================] - 22s 2s/step - loss: 1.0982 - categorical_accuracy: 0.5348 - val_loss: 2.3476 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 15/15
# 11/11 [==============================] - ETA: 0s - loss: 0.9799 - categorical_accuracy: 0.6310
# Epoch 15: saving model to model_init_2023-09-0204_16_33.795128/model-00015-0.97988-0.63102-1.78082-0.37500.h5
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 22s 2s/step - loss: 0.9799 - categorical_accuracy: 0.6310 - val_loss: 1.7808 - val_categorical_accuracy: 0.3750 - lr: 0.0010

# %%
plotModelHistory(model1_history)
# Out:
# Max. Training Accuracy 0.6631016135215759
# Max. Validaiton Accuracy 0.625

# %% [markdown]
# ### Experiment 4
# #### Frames-30, Epoc-30

# %%
# @title Experiment 4

n_frames = 30
num_epochs = 30
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

print(inputShape)
# Out:
# (30, 120, 120, 3)

# %%
model2 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    # Dropout(0.25),

    # Conv3D(64, make3dFilter(3), activation='relu'),
    # MaxPooling3D(pool_size=(1,2,2), padding='same'),
    # BatchNormalization(),
    # # Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.50),


    # Conv3D(64, make3dFilter(5), activation='relu'),
    # MaxPooling3D(pool_size=(1,2,2), padding='same'),
    # BatchNormalization(),


    Dense(5, activation='softmax')
], name="conv_3d2")

# %%
model2.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])

print(model2.summary())

model2_history = model2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
            callbacks=callbacks_list, validation_data=val_generator,
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

plotModelHistory(model2_history)
# Out:
# Model: "conv_3d2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_47 (Conv3D)          (None, 26, 116, 116, 16)  6016
#
#  max_pooling3d_47 (MaxPoolin  (None, 13, 58, 58, 16)   0
#  g3D)
#
#  batch_normalization_68 (Bat  (None, 13, 58, 58, 16)   64
#  chNormalization)
#
#  conv3d_48 (Conv3D)          (None, 11, 56, 56, 32)    13856
#
#  max_pooling3d_48 (MaxPoolin  (None, 11, 28, 28, 32)   0
#  g3D)
#
#  batch_normalization_69 (Bat  (None, 11, 28, 28, 32)   128
#  chNormalization)
#
#  conv3d_49 (Conv3D)          (None, 9, 26, 26, 64)     55360
#
#  max_pooling3d_49 (MaxPoolin  (None, 9, 13, 13, 64)    0
#  g3D)
#
#  batch_normalization_70 (Bat  (None, 9, 13, 13, 64)    256
#  chNormalization)
#
#  flatten_12 (Flatten)        (None, 97344)             0
#
#  dense_33 (Dense)            (None, 128)               12460160
#
#  batch_normalization_71 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_34 (Dense)            (None, 64)                8256
#
#  batch_normalization_72 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_35 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 12,545,189
# Trainable params: 12,544,581
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  /content/drive/My Drive/Project_data/train ; batch size = 64
# ; Num of batches = 10
# <ipython-input-42-17617542d0b6>:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model2_history = model2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# <ipython-input-10-4d0922c185e1>:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/30
# 10/11 [==========================>...] - ETA: 3:35 - loss: 1.8921 - categorical_accuracy: 0.4078; Num of batches = 28
# 11/11 [==============================] - ETA: 0s - loss: 1.8684 - categorical_accuracy: 0.4103  Source path =  /content/drive/My Drive/Project_data/val ; batch size = 64
# ; Num of batches = 1
# ; Num of batches = 2
#
# Epoch 1: saving model to model_init_2023-09-0204_16_33.795128/model-00001-1.86839-0.41026-3.16954-0.29000.h5
# 11/11 [==============================] - 2249s 224s/step - loss: 1.8684 - categorical_accuracy: 0.4103 - val_loss: 3.1695 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 2/30
# 11/11 [==============================] - ETA: 0s - loss: 1.2737 - categorical_accuracy: 0.5573; Num of batches = 3
#
# Epoch 2: saving model to model_init_2023-09-0204_16_33.795128/model-00002-1.27372-0.55731-5.29580-0.20312.h5
# 11/11 [==============================] - 153s 15s/step - loss: 1.2737 - categorical_accuracy: 0.5573 - val_loss: 5.2958 - val_categorical_accuracy: 0.2031 - lr: 0.0010
# Epoch 3/30
# 11/11 [==============================] - ETA: 0s - loss: 1.2632 - categorical_accuracy: 0.5178
# Epoch 3: saving model to model_init_2023-09-0204_16_33.795128/model-00003-1.26315-0.51779-3.62943-0.30357.h5
# 11/11 [==============================] - 120s 12s/step - loss: 1.2632 - categorical_accuracy: 0.5178 - val_loss: 3.6294 - val_categorical_accuracy: 0.3036 - lr: 0.0010
# Epoch 4/30
#  6/11 [===============>..............] - ETA: 34s - loss: 1.1329 - categorical_accuracy: 0.5725; Num of batches = 34
# 11/11 [==============================] - ETA: 0s - loss: 1.0574 - categorical_accuracy: 0.5880; Num of batches = 6
#
# Epoch 4: saving model to model_init_2023-09-0204_16_33.795128/model-00004-1.05737-0.58798-4.07318-0.21875.h5
# 11/11 [==============================] - 71s 7s/step - loss: 1.0574 - categorical_accuracy: 0.5880 - val_loss: 4.0732 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# 11/11 [==============================] - ETA: 0s - loss: 0.4776 - categorical_accuracy: 0.8449
# Epoch 28: saving model to model_init_2023-09-0204_16_33.795128/model-00028-0.47764-0.84492-1.04346-0.62500.h5
# 11/11 [==============================] - 42s 4s/step - loss: 0.4776 - categorical_accuracy: 0.8449 - val_loss: 1.0435 - val_categorical_accuracy: 0.6250 - lr: 1.6000e-06
# Epoch 29/30
# ; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.5126 - categorical_accuracy: 0.8021
# Epoch 29: saving model to model_init_2023-09-0204_16_33.795128/model-00029-0.51256-0.80214-0.75853-0.62500.h5
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 11/11 [==============================] - 43s 4s/step - loss: 0.5126 - categorical_accuracy: 0.8021 - val_loss: 0.7585 - val_categorical_accuracy: 0.6250 - lr: 1.6000e-06
# Epoch 30/30
# 11/11 [==============================] - ETA: 0s - loss: 0.5801 - categorical_accuracy: 0.7754
# Epoch 30: saving model to model_init_2023-09-0204_16_33.795128/model-00030-0.58010-0.77540-0.43838-0.87500.h5
# 11/11 [==============================] - 41s 4s/step - loss: 0.5801 - categorical_accuracy: 0.7754 - val_loss: 0.4384 - val_categorical_accuracy: 0.8750 - lr: 3.2000e-07
# Max. Training Accuracy 0.8449198007583618
# Max. Validaiton Accuracy 0.875

# %% [markdown]
# ### Experiment 5
# #### n_frames = 30 num_epochs = 20

# %%
# @title Experiment 5 - less parameters

n_frames = 30
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

# %%
model3 = Sequential([
    Conv3D(16, make3dFilter(3), padding='same', activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d3")

# %%
model3.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model3.summary())

model3_history = model3.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
            callbacks=callbacks_list, validation_data=val_generator,
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

plotModelHistory(model3_history)
# Out:
# Model: "conv_3d3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_50 (Conv3D)          (None, 30, 120, 120, 16)  1312
#
#  max_pooling3d_50 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  batch_normalization_73 (Bat  (None, 15, 60, 60, 16)   64
#  chNormalization)
#
#  conv3d_51 (Conv3D)          (None, 15, 60, 60, 32)    13856
#
#  max_pooling3d_51 (MaxPoolin  (None, 8, 30, 30, 32)    0
#  g3D)
#
#  batch_normalization_74 (Bat  (None, 8, 30, 30, 32)    128
#  chNormalization)
#
#  conv3d_52 (Conv3D)          (None, 8, 30, 30, 64)     55360
#
#  max_pooling3d_52 (MaxPoolin  (None, 4, 15, 15, 64)    0
#  g3D)
#
#  batch_normalization_75 (Bat  (None, 4, 15, 15, 64)    256
#  chNormalization)
#
#  flatten_13 (Flatten)        (None, 57600)             0
#
#  dense_36 (Dense)            (None, 128)               7372928
#
#  batch_normalization_76 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_37 (Dense)            (None, 64)                8256
#
#  batch_normalization_77 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_38 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 7,453,253
# Trainable params: 7,452,645
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  /content/drive/My Drive/Project_data/train ; batch size = 64
# ; Num of batches = 10
# <ipython-input-45-8c10f2fc9369>:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model3_history = model3.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# <ipython-input-10-4d0922c185e1>:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 10/11 [==========================>...] - ETA: 13s - loss: 1.4661 - categorical_accuracy: 0.4656; Num of batches = 28
# 11/11 [==============================] - ETA: 0s - loss: 1.4533 - categorical_accuracy: 0.4706 Source path =  /content/drive/My Drive/Project_data/val ; batch size = 64
# ; Num of batches = 1
# ; Num of batches = 2
#
# Epoch 1: saving model to model_init_2023-09-0204_16_33.795128/model-00001-1.45332-0.47059-2.28625-0.20000.h5
# 11/11 [==============================] - 167s 16s/step - loss: 1.4533 - categorical_accuracy: 0.4706 - val_loss: 2.2863 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8283 - categorical_accuracy: 0.6996; Num of batches = 3
#
# Epoch 2: saving model to model_init_2023-09-0204_16_33.795128/model-00002-0.82834-0.69960-2.97039-0.21875.h5
# 11/11 [==============================] - 75s 7s/step - loss: 0.8283 - categorical_accuracy: 0.6996 - val_loss: 2.9704 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - ETA: 0s - loss: 0.9567 - categorical_accuracy: 0.6482
# Epoch 3: saving model to model_init_2023-09-0204_16_33.795128/model-00003-0.95672-0.64822-1.83584-0.25000.h5
# 11/11 [==============================] - 70s 7s/step - loss: 0.9567 - categorical_accuracy: 0.6482 - val_loss: 1.8358 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 4/20
#  6/11 [===============>..............] - ETA: 24s - loss: 1.0038 - categorical_accuracy: 0.6232; Num of batches = 34
# 11/11 [==============================] - ETA: 0s - loss: 0.9118 - categorical_accuracy: 0.6695; Num of batches = 6
#
# Epoch 4: saving model to model_init_2023-09-0204_16_33.795128/model-00004-0.91182-0.66953-2.27169-0.25000.h5
# 11/11 [==============================] - 59s 6s/step - loss: 0.9118 - categorical_accuracy: 0.6695 - val_loss: 2.2717 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - ETA: 0s - loss: 0.7791 - categorical_accuracy: 0.6794
# Epoch 5: saving model to model_init_2023-09-0204_16_33.795128/model-00005-0.77913-0.67943-2.50705-0.25000.h5
# 11/11 [==============================] - 51s 5s/step - loss: 0.7791 - categorical_accuracy: 0.6794 - val_loss: 2.5071 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - ETA: 0s - loss: 0.8420 - categorical_accuracy: 0.6794; Num of batches = 25
#
# Epoch 6: saving model to model_init_2023-09-0204_16_33.795128/model-00006-0.84204-0.67943-3.80348-0.00000.h5
# 11/11 [==============================] - 47s 5s/step - loss: 0.8420 - categorical_accuracy: 0.6794 - val_loss: 3.8035 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 7/20
#  8/11 [====================>.........] - ETA: 12s - loss: 0.7909 - categorical_accuracy: 0.6711; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.7458 - categorical_accuracy: 0.7044
# Epoch 7: saving model to model_init_2023-09-0204_16_33.795128/model-00007-0.74580-0.70443-3.55480-0.25000.h5
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 41s 4s/step - loss: 0.4822 - categorical_accuracy: 0.8503 - val_loss: 4.4019 - val_categorical_accuracy: 0.0000e+00 - lr: 4.0000e-05
# Epoch 16/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4705 - categorical_accuracy: 0.8182
# Epoch 16: saving model to model_init_2023-09-0204_16_33.795128/model-00016-0.47054-0.81818-2.80906-0.37500.h5
# 11/11 [==============================] - 41s 4s/step - loss: 0.4705 - categorical_accuracy: 0.8182 - val_loss: 2.8091 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06
# Epoch 17/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4012 - categorical_accuracy: 0.8717
# Epoch 17: saving model to model_init_2023-09-0204_16_33.795128/model-00017-0.40117-0.87166-5.05287-0.00000.h5
# 11/11 [==============================] - 42s 4s/step - loss: 0.4012 - categorical_accuracy: 0.8717 - val_loss: 5.0529 - val_categorical_accuracy: 0.0000e+00 - lr: 8.0000e-06
# Epoch 18/20
#  4/11 [=========>....................] - ETA: 31s - loss: 0.4516 - categorical_accuracy: 0.8235; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.4163 - categorical_accuracy: 0.8449
# Epoch 18: saving model to model_init_2023-09-0204_16_33.795128/model-00018-0.41629-0.84492-2.19891-0.37500.h5
# 11/11 [==============================] - 44s 4s/step - loss: 0.4163 - categorical_accuracy: 0.8449 - val_loss: 2.1989 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06
# Epoch 19/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4276 - categorical_accuracy: 0.8182
# Epoch 19: saving model to model_init_2023-09-0204_16_33.795128/model-00019-0.42757-0.81818-2.18561-0.50000.h5
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 11/11 [==============================] - 42s 4s/step - loss: 0.4276 - categorical_accuracy: 0.8182 - val_loss: 2.1856 - val_categorical_accuracy: 0.5000 - lr: 8.0000e-06
# Epoch 20/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4665 - categorical_accuracy: 0.8289
# Epoch 20: saving model to model_init_2023-09-0204_16_33.795128/model-00020-0.46653-0.82888-3.15526-0.12500.h5
# 11/11 [==============================] - 41s 4s/step - loss: 0.4665 - categorical_accuracy: 0.8289 - val_loss: 3.1553 - val_categorical_accuracy: 0.1250 - lr: 1.6000e-06
# Max. Training Accuracy 0.8716577291488647
# Max. Validaiton Accuracy 0.5

# %% [markdown]
# ### Experiment 6
# #### n_frames = 20 num_epochs = 20 batch_size = 64

# %%
# @title Experiment 6
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

# %%
model4 = Sequential([
    Conv3D(16, make3dFilter(3), padding='same', activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(128, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d4")

# %%
model4.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model4.summary())

model4_history = model4.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
            callbacks=callbacks_list, validation_data=val_generator,
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

plotModelHistory(model4_history)
# Out:
# Model: "conv_3d4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_7 (Conv3D)           (None, 20, 120, 120, 16)  1312
#
#  max_pooling3d_7 (MaxPooling  (None, 10, 60, 60, 16)   0
#  3D)
#
#  batch_normalization_16 (Bat  (None, 10, 60, 60, 16)   64
#  chNormalization)
#
#  conv3d_8 (Conv3D)           (None, 10, 60, 60, 32)    13856
#
#  max_pooling3d_8 (MaxPooling  (None, 5, 30, 30, 32)    0
#  3D)
#
#  batch_normalization_17 (Bat  (None, 5, 30, 30, 32)    128
#  chNormalization)
#
#  conv3d_9 (Conv3D)           (None, 5, 30, 30, 64)     55360
#
#  max_pooling3d_9 (MaxPooling  (None, 3, 15, 15, 64)    0
#  3D)
#
#  batch_normalization_18 (Bat  (None, 3, 15, 15, 64)    256
#  chNormalization)
#
#  conv3d_10 (Conv3D)          (None, 3, 15, 15, 128)    221312
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 8, 8, 128)     0
#  g3D)
#
#  batch_normalization_19 (Bat  (None, 2, 8, 8, 128)     512
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 16384)             0
#
#  dense_8 (Dense)             (None, 128)               2097280
#
#  batch_normalization_20 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  batch_normalization_21 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 2,399,429
# Trainable params: 2,398,565
# Non-trainable params: 864
# _________________________________________________________________
# None
# Source path =  /content/drive/My Drive/Project_data/train ; batch size = 64
# ; Num of batches = 10
# <ipython-input-32-622e5b081a0b>:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model4_history = model4.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# <ipython-input-11-4d0922c185e1>:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 10/11 [==========================>...] - ETA: 9s - loss: 1.4206 - categorical_accuracy: 0.4828 ; Num of batches = 28
# 11/11 [==============================] - ETA: 0s - loss: 1.4014 - categorical_accuracy: 0.4887Source path =  /content/drive/My Drive/Project_data/val ; batch size = 64
# ; Num of batches = 1
# ; Num of batches = 2
#
# Epoch 1: saving model to model_init_2023-09-0503_44_31.462170/model-00001-1.40136-0.48869-1.52755-0.30000.h5
# 11/11 [==============================] - 120s 12s/step - loss: 1.4014 - categorical_accuracy: 0.4887 - val_loss: 1.5276 - val_categorical_accuracy: 0.3000 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - ETA: 0s - loss: 0.9811 - categorical_accuracy: 0.6245; Num of batches = 3
#
# Epoch 2: saving model to model_init_2023-09-0503_44_31.462170/model-00002-0.98113-0.62451-1.51747-0.32812.h5
# 11/11 [==============================] - 51s 5s/step - loss: 0.9811 - categorical_accuracy: 0.6245 - val_loss: 1.5175 - val_categorical_accuracy: 0.3281 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - ETA: 0s - loss: 0.9791 - categorical_accuracy: 0.6245
# Epoch 3: saving model to model_init_2023-09-0503_44_31.462170/model-00003-0.97909-0.62451-1.60671-0.44643.h5
# 11/11 [==============================] - 48s 5s/step - loss: 0.9791 - categorical_accuracy: 0.6245 - val_loss: 1.6067 - val_categorical_accuracy: 0.4464 - lr: 0.0010
img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model6 = Sequential([
    TimeDistributed(Conv2D(16, make2dFilter(3), padding='same', activation='relu'), input_shape=inputShape),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(32, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(64, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(128, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(256, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Flatten()),
    LSTM(256),
    Dropout(0.2),

    Dense(256, activation='relu'),
    Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_2d_lstm")

# %%
model6.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model6.summary())

model6_history = model6.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
            callbacks=callbacks_list, validation_data=val_generator,
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

plotModelHistory(model6_history)
# Out:
# Model: "conv_2d_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 20, 120, 120, 16)  448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 20, 120, 120, 16)  64
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 20, 60, 60, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 20, 60, 60, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 20, 60, 60, 32)   128
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 20, 30, 30, 32)   0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 20, 30, 30, 64)   18496
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 20, 30, 30, 64)   256
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 20, 15, 15, 64)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 20, 15, 15, 128)  73856
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 20, 15, 15, 128)  512
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 20, 7, 7, 128)    0
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 20, 7, 7, 256)    295168
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 20, 7, 7, 256)    1024
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 20, 3, 3, 256)    0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 20, 2304)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 256)               2622464
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 3,084,133
# Trainable params: 3,083,141
# Non-trainable params: 992
# _________________________________________________________________
# None
# Source path =  /content/drive/My Drive/Project_data/train ; batch size = 32
# ; Num of batches = 20
# <ipython-input-26-af1e63cde370>:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model6_history = model6.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# <ipython-input-11-4d0922c185e1>:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/30
# 20/21 [===========================>..] - ETA: 6:42 - loss: 1.3261 - categorical_accuracy: 0.4375 ; Num of batches = 28
# 21/21 [==============================] - ETA: 0s - loss: 1.3111 - categorical_accuracy: 0.4434  Source path =  /content/drive/My Drive/Project_data/val ; batch size = 32
# ; Num of batches = 3
# ; Num of batches = 25
#
# Epoch 1: saving model to model_init_2023-09-0503_44_31.462170/model-00001-1.31114-0.44344-1.54648-0.33000.h5
# 21/21 [==============================] - 8931s 446s/step - loss: 1.3111 - categorical_accuracy: 0.4434 - val_loss: 1.5465 - val_categorical_accuracy: 0.3300 - lr: 0.0010
# Epoch 2/30
# 21/21 [==============================] - ETA: 0s - loss: 1.0429 - categorical_accuracy: 0.5673
# Epoch 2: saving model to model_init_2023-09-0503_44_31.462170/model-00002-1.04288-0.56729-1.90707-0.25000.h5
# 21/21 [==============================] - 287s 14s/step - loss: 1.0429 - categorical_accuracy: 0.5673 - val_loss: 1.9071 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch
30
# 21/21 [==============================] - ETA: 0s - loss: 0.1718 - categorical_accuracy: 0.9496; Num of batches = 25
#
# Epoch 26: saving model to model_init_2023-09-0503_44_31.462170/model-00026-0.17180-0.94958-1.17778-0.68750.h5
# 21/21 [==============================] - 57s 3s/step - loss: 0.1718 - categorical_accuracy: 0.9496 - val_loss: 1.1778 - val_categorical_accuracy: 0.6875 - lr: 1.6000e-06
# Epoch 27/30
#  6/21 [=======>......................] - ETA: 36s - loss: 0.2026 - categorical_accuracy: 0.9216; Num of batches = 39
# 21/21 [==============================] - ETA: 0s - loss: 0.2021 - categorical_accuracy: 0.9328
# Epoch 27: saving model to model_init_2023-09-0503_44_31.462170/model-00027-0.20211-0.93277-1.61867-0.50000.h5
# 21/21 [==============================] - 54s 3s/step - loss: 0.2021 - categorical_accuracy: 0.9328 - val_loss: 1.6187 - val_categorical_accuracy: 0.5000 - lr: 1.6000e-06
# Epoch 28/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1953 - categorical_accuracy: 0.9468
# Epoch 28: saving model to model_init_2023-09-0503_44_31.462170/model-00028-0.19530-0.94678-1.90320-0.50000.h5
# 21/21 [==============================] - 57s 3s/step - loss: 0.1953 - categorical_accuracy: 0.9468 - val_loss: 1.9032 - val_categorical_accuracy: 0.5000 - lr: 1.6000e-06
# Epoch 29/30
#  3/21 [===>..........................] - ETA: 45s - loss: 0.2729 - categorical_accuracy: 0.9020; Num of batches = 39
# 21/21 [==============================] - ETA: 0s - loss: 0.1889 - categorical_accuracy: 0.9496
# Epoch 29: saving model to model_init_2023-09-0503_44_31.462170/model-00029-0.18887-0.94958-0.28520-0.87500.h5
# 21/21 [==============================] - 55s 3s/step - loss: 0.1889 - categorical_accuracy: 0.9496 - val_loss: 0.2852 - val_categorical_accuracy: 0.8750 - lr: 1.6000e-06
# Epoch 30/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1772 - categorical_accuracy: 0.9468
# Epoch 30: saving model to model_init_2023-09-0503_44_31.462170/model-00030-0.17720-0.94678-0.54284-0.68750.h5
# 21/21 [==============================] - 57s 3s/step - loss: 0.1772 - categorical_accuracy: 0.9468 - val_loss: 0.5428 - val_categorical_accuracy: 0.6875 - lr: 1.6000e-06

# %% [markdown]
# ### Experiment 8

# %%
# @title Experiment 8 - Transfer learning
from tensorflow.keras.applications import mobilenet
from tensorflow.keras.applications import MobileNet

# %%
n_frames = 20
num_epochs = 30
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

print(inputShape)

# model7 = # Create a Sequential model
model7 = Sequential()

model7.add(TimeDistributed(MobileNet(weights='imagenet', include_top=False), input_shape=(None, 120, 120, 3)))

for layer in model7.layers:
    layer.trainable = False

model7.add(TimeDistributed(BatchNormalization()))
model7.add(TimeDistributed(MaxPooling2D(make2dFilter(2))))
model7.add(TimeDistributed(Flatten()))

model7.add(LSTM(256))
model7.add(Dropout(0.2))

model7.add(Dense(256,activation='relu'))
model7.add(Dropout(0.2))

model7.add(Dense(5, activation='softmax'))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# (20, 120, 120, 3)

# %%
model7.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model7.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_1 (TimeDis  (None, None, 3, 3, 1024)  3228864
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, None, 3, 3, 1024)  4096
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, None, 1, 1, 1024)  0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, None, 1024)       0
#  tributed)
#
#  lstm (LSTM)                 (None, 256)               1311744
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 4,611,781
# Trainable params: 1,380,869
# Non-trainable params: 3,230,912
# _________________________________________________________________
# None

# %%
model7_history = model7.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
            callbacks=callbacks_list, validation_data=val_generator,
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

plotModelHistory(model7_history)
# Out:
# 10/11 [==========================>...] - ETA: 4:34 - loss: 1.3622 - categorical_accuracy: 0.4422; Num of batches = 28
# 11/11 [==============================] - ETA: 0s - loss: 1.3426 - categorical_accuracy: 0.4570  Source path =  /content/drive/My Drive/Project_data/val ; batch size = 64
# ; Num of batches = 1
# ; Num of batches = 2
#
# Epoch 1: saving model to model_init_2023-09-0407_58_02.511816/model-00001-1.34261-0.45701-1.10092-0.60000.h5
# 11/11 [==============================] - 2853s 284s/step - loss: 1.3426 - categorical_accuracy: 0.4570 - val_loss: 1.1009 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 2/30
# 11/11 [==============================] - ETA: 0s - loss: 0.6482 - categorical_accuracy: 0.7668; Num of batches = 3
#
# Epoch 2: saving model to model_init_2023-09-0407_58_02.511816/model-00002-0.64821-0.76680-0.88973-0.67188.h5
# 11/11 [==============================] - 128s 13s/step - loss: 0.6482 - categorical_accuracy: 0.7668 - val_loss: 0.8897 - val_categorical_accuracy: 0.6719 - lr: 0.0010
# Epoch 3/30
# 11/11 [==============================] - ETA: 0s - loss: 0.5605 - categorical_accuracy: 0.8063
# Epoch 3: saving model to model_init_2023-09-0407_58_02.511816/model-00003-0.56052-0.80632-0.74806-0.75000.h5
# 11/11 [==============================] - 128s 13s/step - loss: 0.5605 - categorical_accuracy: 0.8063 - val_loss: 0.7481 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 4/30
#  6/11 [===============>..............] - ETA: 34s - loss: 0.4322 - categorical_accuracy: 0.8551; Num of batches = 34
# 11/11 [==============================] - ETA: 0s - loss: 0.3224 - categorical_accuracy: 0.9013; Num of batches = 6
#
# Epoch 4: saving model to model_init_2023-09-0407_58_02.511816/model-00004-0.32237-0.90129-1.01708-0.56250.h5
# 11/11 [==============================] - 56s 6s/step - loss: 0.3224 - categorical_accuracy: 0.9013 - val_loss: 1.0171 - val_categorical_accuracy: 0.5625 - lr: 0.0010
# Epoch 5/30
# 11/11 [==============================] - ETA: 0s - loss: 0.2153 - categorical_accuracy: 0.9378
# Epoch 5: saving model to model_init_2023-09-0407_58_02.511816/model-00005-0.21534-0.93780-1.02410-0.65625.h5
# 11/11 [==============================] - 42s 4s/step - loss: 0.2153 - categorical_accuracy: 0.9378 - val_loss: 1.0241 - val_categorical_accuracy: 0.6562 - lr: 0.0010
# Epoch 6/30
# 11/11 [==============================] - ETA: 0s - loss: 0.2342 - categorical_accuracy: 0.9234; Num of batches = 25
#
# Epoch 6: saving model to model_init_2023-09-0407_58_02.511816/model-00006-0.23425-0.92344-1.14836-0.37500.h5
# 11/11 [==============================] - 31s 3s/step - loss: 0.2342 - categorical_accuracy: 0.9234 - val_loss: 1.1484 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 7/30
#  8/11 [====================>.........] - ETA: 8s - loss: 0.1793 - categorical_accuracy: 0.9342 ; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.1617 - categorical_accuracy: 0.9458
# Epoch 7: saving model to model_init_2023-09-0407_58_02.511816/model-00007-0.16173-0.94581-0.33078-1.00000.h5
# 11/11 [==============================] - 31s 3s/step - loss: 0.1617 - categorical_accuracy: 0.9458 - val_loss: 0.3308 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 8/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0999 - categorical_accuracy: 0.9733
# Epoch 8: saving model to model_init_2023-09-0407_58_02.511816/model-00008-0.09986-0.97326-0.30273-1.00000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0999 - categorical_accuracy: 0.9733 - val_loss: 0.3027 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/30
# 11/11 [==============================] - ETA: 0s - loss: 0.1084 - categorical_accuracy: 0.9679
# Epoch 9: saving model to model_init_2023-09-0407_58_02.511816/model-00009-0.10845-0.96791-1.42928-0.50000.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.1084 - categorical_accuracy: 0.9679 - val_loss: 1.4293 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 10/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0868 - categorical_accuracy: 0.9786
# Epoch 10: saving model to model_init_2023-09-0407_58_02.511816/model-00010-0.08679-0.97861-1.03441-0.50000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0868 - categorical_accuracy: 0.9786 - val_loss: 1.0344 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 11/30
#  3/11 [=======>......................] - ETA: 18s - loss: 0.1203 - categorical_accuracy: 0.9608; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0744 - categorical_accuracy: 0.9786
# Epoch 11: saving model to model_init_2023-09-0407_58_02.511816/model-00011-0.07443-0.97861-0.93013-0.75000.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.0744 - categorical_accuracy: 0.9786 - val_loss: 0.9301 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 12/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0500 - categorical_accuracy: 0.9840
# Epoch 12: saving model to model_init_2023-09-0407_58_02.511816/model-00012-0.05004-0.98396-0.88621-0.50000.h5
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 27s 3s/step - loss: 0.0500 - categorical_accuracy: 0.9840 - val_loss: 0.8862 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 13/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0572 - categorical_accuracy: 0.9786
# Epoch 13: saving model to model_init_2023-09-0407_58_02.511816/model-00013-0.05722-0.97861-1.28091-0.75000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0572 - categorical_accuracy: 0.9786 - val_loss: 1.2809 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 14/30
#  9/11 [=======================>......] - ETA: 4s - loss: 0.0413 - categorical_accuracy: 0.9869; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0402 - categorical_accuracy: 0.9893; Num of batches = 25
#
# Epoch 14: saving model to model_init_2023-09-0407_58_02.511816/model-00014-0.04025-0.98930-0.31519-0.75000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0402 - categorical_accuracy: 0.9893 - val_loss: 0.3152 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 15/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0399 - categorical_accuracy: 0.9893
# Epoch 15: saving model to model_init_2023-09-0407_58_02.511816/model-00015-0.03994-0.98930-0.82774-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0399 - categorical_accuracy: 0.9893 - val_loss: 0.8277 - val_categorical_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 16/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0182 - categorical_accuracy: 1.0000
# Epoch 16: saving model to model_init_2023-09-0407_58_02.511816/model-00016-0.01819-1.00000-1.11537-0.75000.h5
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 28s 3s/step - loss: 0.0182 - categorical_accuracy: 1.0000 - val_loss: 1.1154 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 17/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0202 - categorical_accuracy: 0.9947
# Epoch 17: saving model to model_init_2023-09-0407_58_02.511816/model-00017-0.02020-0.99465-1.40434-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0202 - categorical_accuracy: 0.9947 - val_loss: 1.4043 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-05
# Epoch 18/30
#  4/11 [=========>....................] - ETA: 19s - loss: 0.0217 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0190 - categorical_accuracy: 1.0000
# Epoch 18: saving model to model_init_2023-09-0407_58_02.511816/model-00018-0.01900-1.00000-0.03571-1.00000.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.0190 - categorical_accuracy: 1.0000 - val_loss: 0.0357 - val_categorical_accuracy: 1.0000 - lr: 4.0000e-05
# Epoch 19/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0195 - categorical_accuracy: 1.0000
# Epoch 19: saving model to model_init_2023-09-0407_58_02.511816/model-00019-0.01947-1.00000-0.10618-1.00000.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0195 - categorical_accuracy: 1.0000 - val_loss: 0.1062 - val_categorical_accuracy: 1.0000 - lr: 4.0000e-05
# Epoch 20/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0145 - categorical_accuracy: 1.0000
# Epoch 20: saving model to model_init_2023-09-0407_58_02.511816/model-00020-0.01447-1.00000-1.30910-0.50000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0145 - categorical_accuracy: 1.0000 - val_loss: 1.3091 - val_categorical_accuracy: 0.5000 - lr: 4.0000e-05
# Epoch 21/30
# 10/11 [==========================>...] - ETA: 2s - loss: 0.0128 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0128 - categorical_accuracy: 1.0000
# Epoch 21: saving model to model_init_2023-09-0407_58_02.511816/model-00021-0.01277-1.00000-1.09789-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0128 - categorical_accuracy: 1.0000 - val_loss: 1.0979 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-05
# Epoch 22/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0219 - categorical_accuracy: 0.9947
# Epoch 22: saving model to model_init_2023-09-0407_58_02.511816/model-00022-0.02190-0.99465-0.50003-0.75000.h5
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 28s 3s/step - loss: 0.0219 - categorical_accuracy: 0.9947 - val_loss: 0.5000 - val_categorical_accuracy: 0.7500 - lr: 4.0000e-05
# Epoch 23/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0171 - categorical_accuracy: 0.9947; Num of batches = 25
#
# Epoch 23: saving model to model_init_2023-09-0407_58_02.511816/model-00023-0.01714-0.99465-0.96820-0.87500.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0171 - categorical_accuracy: 0.9947 - val_loss: 0.9682 - val_categorical_accuracy: 0.8750 - lr: 8.0000e-06
# Epoch 24/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0133 - categorical_accuracy: 1.0000
# Epoch 24: saving model to model_init_2023-09-0407_58_02.511816/model-00024-0.01334-1.00000-1.02947-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0133 - categorical_accuracy: 1.0000 - val_loss: 1.0295 - val_categorical_accuracy: 0.6250 - lr: 8.0000e-06
# Epoch 25/30
#  5/11 [============>.................] - ETA: 14s - loss: 0.0109 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0104 - categorical_accuracy: 1.0000
# Epoch 25: saving model to model_init_2023-09-0407_58_02.511816/model-00025-0.01037-1.00000-1.53683-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0104 - categorical_accuracy: 1.0000 - val_loss: 1.5368 - val_categorical_accuracy: 0.6250 - lr: 8.0000e-06
# Epoch 26/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0155 - categorical_accuracy: 1.0000
# Epoch 26: saving model to model_init_2023-09-0407_58_02.511816/model-00026-0.01549-1.00000-1.19222-0.50000.h5
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 11/11 [==============================] - 29s 3s/step - loss: 0.0155 - categorical_accuracy: 1.0000 - val_loss: 1.1922 - val_categorical_accuracy: 0.5000 - lr: 8.0000e-06
# Epoch 27/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0132 - categorical_accuracy: 0.9947
# Epoch 27: saving model to model_init_2023-09-0407_58_02.511816/model-00027-0.01320-0.99465-1.03137-0.50000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.0132 - categorical_accuracy: 0.9947 - val_loss: 1.0314 - val_categorical_accuracy: 0.5000 - lr: 1.6000e-06
# Epoch 28/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0141 - categorical_accuracy: 1.0000
# Epoch 28: saving model to model_init_2023-09-0407_58_02.511816/model-00028-0.01408-1.00000-0.96454-0.62500.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0141 - categorical_accuracy: 1.0000 - val_loss: 0.9645 - val_categorical_accuracy: 0.6250 - lr: 1.6000e-06
# Epoch 29/30
# ; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0131 - categorical_accuracy: 1.0000
# Epoch 29: saving model to model_init_2023-09-0407_58_02.511816/model-00029-0.01311-1.00000-0.34271-0.87500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0131 - categorical_accuracy: 1.0000 - val_loss: 0.3427 - val_categorical_accuracy: 0.8750 - lr: 1.6000e-06
# Epoch 30/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0125 - categorical_accuracy: 1.0000
# Epoch 30: saving model to model_init_2023-09-0407_58_02.511816/model-00030-0.01249-1.00000-0.81861-0.87500.h5
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 11/11 [==============================] - 29s 3s/step - loss: 0.0125 - categorical_accuracy: 1.0000 - val_loss: 0.8186 - val_categorical_accuracy: 0.8750 - lr: 1.6000e-06
# <ipython-input-29-ea84de0b3714>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model7_history = model7.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# <ipython-input-11-4d0922c185e1>:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0132 - categorical_accuracy: 1.0000; Num of batches = 25
#
# Epoch 1: saving model to model_init_2023-09-0407_58_02.511816/model-00001-0.01317-1.00000-1.45341-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0132 - categorical_accuracy: 1.0000 - val_loss: 1.4534 - val_categorical_accuracy: 0.6250 - lr: 3.2000e-07
# Epoch 2/30
#  5/11 [============>.................] - ETA: 14s - loss: 0.0254 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0188 - categorical_accuracy: 1.0000
# Epoch 2: saving model to model_init_2023-09-0407_58_02.511816/model-00002-0.01880-1.00000-0.05036-1.00000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0188 - categorical_accuracy: 1.0000 - val_loss: 0.0504 - val_categorical_accuracy: 1.0000 - lr: 3.2000e-07
# Epoch 3/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0148 - categorical_accuracy: 1.0000
# Epoch 3: saving model to model_init_2023-09-0407_58_02.511816/model-00003-0.01481-1.00000-1.39490-0.50000.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.0148 - categorical_accuracy: 1.0000 - val_loss: 1.3949 - val_categorical_accuracy: 0.5000 - lr: 3.2000e-07
# Epoch 4/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0070 - categorical_accuracy: 1.0000
# Epoch 4: saving model to model_init_2023-09-0407_58_02.511816/model-00004-0.00699-1.00000-1.29503-0.62500.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.0070 - categorical_accuracy: 1.0000 - val_loss: 1.2950 - val_categorical_accuracy: 0.6250 - lr: 3.2000e-07
# Epoch 5/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0259 - categorical_accuracy: 0.9840
# Epoch 5: saving model to model_init_2023-09-0407_58_02.511816/model-00005-0.02592-0.98396-0.38679-0.75000.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0259 - categorical_accuracy: 0.9840 - val_loss: 0.3868 - val_categorical_accuracy: 0.7500 - lr: 3.2000e-07
# Epoch 6/30
# ; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0101 - categorical_accuracy: 1.0000
# Epoch 6: saving model to model_init_2023-09-0407_58_02.511816/model-00006-0.01007-1.00000-1.08389-0.50000.h5
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 11/11 [==============================] - 28s 3s/step - loss: 0.0101 - categorical_accuracy: 1.0000 - val_loss: 1.0839 - val_categorical_accuracy: 0.5000 - lr: 3.2000e-07
# Epoch 7/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0214 - categorical_accuracy: 0.9893
# Epoch 7: saving model to model_init_2023-09-0407_58_02.511816/model-00007-0.02137-0.98930-0.85586-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0214 - categorical_accuracy: 0.9893 - val_loss: 0.8559 - val_categorical_accuracy: 0.6250 - lr: 6.4000e-08
# Epoch 8/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0109 - categorical_accuracy: 1.0000
# Epoch 8: saving model to model_init_2023-09-0407_58_02.511816/model-00008-0.01085-1.00000-1.32517-0.75000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.0109 - categorical_accuracy: 1.0000 - val_loss: 1.3252 - val_categorical_accuracy: 0.7500 - lr: 6.4000e-08
# Epoch 9/30
#  6/11 [===============>..............] - ETA: 12s - loss: 0.0191 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0166 - categorical_accuracy: 1.0000; Num of batches = 25
#
# Epoch 9: saving model to model_init_2023-09-0407_58_02.511816/model-00009-0.01657-1.00000-0.91032-0.50000.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.0166 - categorical_accuracy: 1.0000 - val_loss: 0.9103 - val_categorical_accuracy: 0.5000 - lr: 6.4000e-08
# Epoch 10/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0131 - categorical_accuracy: 1.0000
# Epoch 10: saving model to model_init_2023-09-0407_58_02.511816/model-00010-0.01310-1.00000-1.28585-0.50000.h5
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 11/11 [==============================] - 28s 3s/step - loss: 0.0131 - categorical_accuracy: 1.0000 - val_loss: 1.2859 - val_categorical_accuracy: 0.5000 - lr: 6.4000e-08
# Epoch 11/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0245 - categorical_accuracy: 1.0000
# Epoch 11: saving model to model_init_2023-09-0407_58_02.511816/model-00011-0.02455-1.00000-0.08402-1.00000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.0245 - categorical_accuracy: 1.0000 - val_loss: 0.0840 - val_categorical_accuracy: 1.0000 - lr: 1.2800e-08
# Epoch 12/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0123 - categorical_accuracy: 1.0000
# Epoch 12: saving model to model_init_2023-09-0407_58_02.511816/model-00012-0.01226-1.00000-0.43253-0.87500.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.0123 - categorical_accuracy: 1.0000 - val_loss: 0.4325 - val_categorical_accuracy: 0.8750 - lr: 1.2800e-08
# Epoch 13/30
#  1/11 [=>............................] - ETA: 1s - loss: 0.0040 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0160 - categorical_accuracy: 1.0000
# Epoch 13: saving model to model_init_2023-09-0407_58_02.511816/model-00013-0.01600-1.00000-0.56907-0.75000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.0160 - categorical_accuracy: 1.0000 - val_loss: 0.5691 - val_categorical_accuracy: 0.7500 - lr: 1.2800e-08
# Epoch 14/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0205 - categorical_accuracy: 1.0000
# Epoch 14: saving model to model_init_2023-09-0407_58_02.511816/model-00014-0.02047-1.00000-0.98669-0.62500.h5
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 11/11 [==============================] - 28s 3s/step - loss: 0.0205 - categorical_accuracy: 1.0000 - val_loss: 0.9867 - val_categorical_accuracy: 0.6250 - lr: 1.2800e-08
# Epoch 15/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0132 - categorical_accuracy: 1.0000
# Epoch 15: saving model to model_init_2023-09-0407_58_02.511816/model-00015-0.01316-1.00000-1.21134-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0132 - categorical_accuracy: 1.0000 - val_loss: 1.2113 - val_categorical_accuracy: 0.6250 - lr: 2.5600e-09
# Epoch 16/30
#  7/11 [==================>...........] - ETA: 9s - loss: 0.0164 - categorical_accuracy: 1.0000 ; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0175 - categorical_accuracy: 0.9947
# Epoch 16: saving model to model_init_2023-09-0407_58_02.511816/model-00016-0.01750-0.99465-0.88949-0.75000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.0175 - categorical_accuracy: 0.9947 - val_loss: 0.8895 - val_categorical_accuracy: 0.7500 - lr: 2.5600e-09
# Epoch 17/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0179 - categorical_accuracy: 0.9947
# Epoch 17: saving model to model_init_2023-09-0407_58_02.511816/model-00017-0.01789-0.99465-1.41726-0.75000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.0179 - categorical_accuracy: 0.9947 - val_loss: 1.4173 - val_categorical_accuracy: 0.7500 - lr: 2.5600e-09
# Epoch 18/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0223 - categorical_accuracy: 1.0000; Num of batches = 25
#
# Epoch 18: saving model to model_init_2023-09-0407_58_02.511816/model-00018-0.02227-1.00000-0.97029-0.62500.h5
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 11/11 [==============================] - 27s 3s/step - loss: 0.0223 - categorical_accuracy: 1.0000 - val_loss: 0.9703 - val_categorical_accuracy: 0.6250 - lr: 2.5600e-09
# Epoch 19/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0083 - categorical_accuracy: 1.0000
# Epoch 19: saving model to model_init_2023-09-0407_58_02.511816/model-00019-0.00833-1.00000-1.82358-0.50000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0083 - categorical_accuracy: 1.0000 - val_loss: 1.8236 - val_categorical_accuracy: 0.5000 - lr: 5.1200e-10
# Epoch 20/30
#  2/11 [====>.........................] - ETA: 20s - loss: 0.0227 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0214 - categorical_accuracy: 0.9947
# Epoch 20: saving model to model_init_2023-09-0407_58_02.511816/model-00020-0.02139-0.99465-0.42585-0.75000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0214 - categorical_accuracy: 0.9947 - val_loss: 0.4258 - val_categorical_accuracy: 0.7500 - lr: 5.1200e-10
# Epoch 21/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0133 - categorical_accuracy: 1.0000
# Epoch 21: saving model to model_init_2023-09-0407_58_02.511816/model-00021-0.01328-1.00000-0.16469-0.87500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0133 - categorical_accuracy: 1.0000 - val_loss: 0.1647 - val_categorical_accuracy: 0.8750 - lr: 5.1200e-10
# Epoch 22/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0080 - categorical_accuracy: 1.0000
# Epoch 22: saving model to model_init_2023-09-0407_58_02.511816/model-00022-0.00799-1.00000-0.23901-0.87500.h5
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# 11/11 [==============================] - 27s 3s/step - loss: 0.0080 - categorical_accuracy: 1.0000 - val_loss: 0.2390 - val_categorical_accuracy: 0.8750 - lr: 5.1200e-10
# Epoch 23/30
#  8/11 [====================>.........] - ETA: 7s - loss: 0.0143 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0147 - categorical_accuracy: 1.0000
# Epoch 23: saving model to model_init_2023-09-0407_58_02.511816/model-00023-0.01471-1.00000-1.45647-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0147 - categorical_accuracy: 1.0000 - val_loss: 1.4565 - val_categorical_accuracy: 0.6250 - lr: 1.0240e-10
# Epoch 24/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0127 - categorical_accuracy: 1.0000
# Epoch 24: saving model to model_init_2023-09-0407_58_02.511816/model-00024-0.01268-1.00000-0.13606-0.87500.h5
# 11/11 [==============================] - 30s 3s/step - loss: 0.0127 - categorical_accuracy: 1.0000 - val_loss: 0.1361 - val_categorical_accuracy: 0.8750 - lr: 1.0240e-10
# Epoch 25/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0078 - categorical_accuracy: 1.0000
# Epoch 25: saving model to model_init_2023-09-0407_58_02.511816/model-00025-0.00782-1.00000-1.23002-0.62500.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.0078 - categorical_accuracy: 1.0000 - val_loss: 1.2300 - val_categorical_accuracy: 0.6250 - lr: 1.0240e-10
# Epoch 26/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0170 - categorical_accuracy: 1.0000; Num of batches = 25
#
# Epoch 26: saving model to model_init_2023-09-0407_58_02.511816/model-00026-0.01703-1.00000-1.55649-0.50000.h5
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# 11/11 [==============================] - 28s 3s/step - loss: 0.0170 - categorical_accuracy: 1.0000 - val_loss: 1.5565 - val_categorical_accuracy: 0.5000 - lr: 1.0240e-10
# Epoch 27/30
#  3/11 [=======>......................] - ETA: 18s - loss: 0.0131 - categorical_accuracy: 1.0000; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0172 - categorical_accuracy: 1.0000
# Epoch 27: saving model to model_init_2023-09-0407_58_02.511816/model-00027-0.01720-1.00000-1.88172-0.50000.h5
# 11/11 [==============================] - 29s 3s/step - loss: 0.0172 - categorical_accuracy: 1.0000 - val_loss: 1.8817 - val_categorical_accuracy: 0.5000 - lr: 2.0480e-11
# Epoch 28/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0131 - categorical_accuracy: 1.0000
# Epoch 28: saving model to model_init_2023-09-0407_58_02.511816/model-00028-0.01312-1.00000-0.21019-0.87500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.0131 - categorical_accuracy: 1.0000 - val_loss: 0.2102 - val_categorical_accuracy: 0.8750 - lr: 2.0480e-11
# Epoch 29/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - categorical_accuracy: 1.0000
# Epoch 29: saving model to model_init_2023-09-0407_58_02.511816/model-00029-0.00896-1.00000-0.82216-0.50000.h5
# 11/11 [==============================] - 28s 3s/step - loss: 0.0090 - categorical_accuracy: 1.0000 - val_loss: 0.8222 - val_categorical_accuracy: 0.5000 - lr: 2.0480e-11
# Epoch 30/30
#  9/11 [=======================>......] - ETA: 5s - loss: 0.0160 - categorical_accuracy: 0.9935; Num of batches = 39
# 11/11 [==============================] - ETA: 0s - loss: 0.0147 - categorical_accuracy: 0.9947
# Epoch 30: saving model to model_init_2023-09-0407_58_02.511816/model-00030-0.01465-0.99465-0.13763-1.00000.h5
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# 11/11 [==============================] - 29s 3s/step - loss: 0.0147 - categorical_accuracy: 0.9947 - val_loss: 0.1376 - val_categorical_accuracy: 1.0000 - lr: 2.0480e-11
# Max. Training Accuracy 1.0
# Max. Validaiton Accuracy 1.0
